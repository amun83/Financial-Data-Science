# %% [markdown]
# <a href="https://colab.research.google.com/github/amun83/Koscom-Financial-Data-Bootcamp/blob/master/FD103_Forecasting_Natural_Gas_ETN_Prices_ARIMA_vs_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
ON_COLAB = True
DATA_PATH = ''
# !python --version
# Out:
# Python 3.6.7

# %%
# !pip install -q --upgrade pystan
# !pip install -q --upgrade fbprophet
#!pip install -q --upgrade tensorflow
#!pip install -q --upgrade keras
#!pip install -q --upgrade pandas_datareader
#!pip install -q --upgrade finance-datareader
#!pip install -q --upgrade html5lib
#!pip install -q --upgrade lxml
# !pip install -q --upgrade seaborn
# !pip install -q --upgrade gspread

# %%
# utilities
import datetime
import re
from IPython.display import display

# web scraping
#import requests
#import urllib.parse
#from bs4 import BeautifulSoup
#import pandas_datareader as pdr
#import FinanceDataReader as fdr

# Math/Stat
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import math
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot
from fbprophet.plot import plot_yearly
from fbprophet.plot import plot_cross_validation_metric
from fbprophet.diagnostics import cross_validation
from fbprophet.diagnostics import performance_metrics

# Machine Learning
from sklearn.preprocessing import scale, robust_scale, minmax_scale, maxabs_scale
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# visualization
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
# %matplotlib inline

sns.__version__
# Out:
# '0.9.0'

# %% [markdown]
# ## Summary
# * EDA
# * ARIMA : Facebook Prophet
# * Deep Learning : Keras

# %% [markdown]
# ## 데이터 준비 I

# %%
if ON_COLAB :
  from google.colab import drive
  drive.mount('/gdrive')
  DATA_PATH = '/gdrive/My Drive/Natural Gas Data/'
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Dow Jones Commodity Index Natural Gas TR
with open(DATA_PATH + 'DJCI.csv', 'r') as f:
  df_DJCI = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_DJCI.head(3), df_DJCI.tail(3))
# Out:
#                 Dow Jones Commodity Index Natural Gas TR  \
# Effective date
# 2018-11-16                                          0.85
# 2018-11-15                                          0.80
# 2018-11-14                                          0.97
#
#                 Dow Jones Commodity Index Natural Gas ER  \
# Effective date
# 2018-11-16                                          0.60
# 2018-11-15                                          0.56
# 2018-11-14                                          0.68
#
#                 Dow Jones Commodity Index Natural Gas
# Effective date
# 2018-11-16                                     233.33
# 2018-11-15                                     219.85
# 2018-11-14                                     266.34
#                 Dow Jones Commodity Index Natural Gas TR  \
# Effective date
# 2008-11-04                                         21.64
# 2008-11-03                                         20.50
# 2008-10-31                                         20.33
#
#                 Dow Jones Commodity Index Natural Gas ER  \
# Effective date
# 2008-11-04                                         15.70
# 2008-11-03                                         14.87
# 2008-10-31                                         14.75
#
#                 Dow Jones Commodity Index Natural Gas
# Effective date
# 2008-11-04                                     392.55
# 2008-11-03                                     371.83
# 2008-10-31                                     368.84

# %%
# Henry Hub Natural Gas Spot
with open(DATA_PATH + 'NG_Spot.csv', 'r') as f:
  df_Spot = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_Spot.head(3), df_Spot.tail(3))
# Out:
#             Henry Hub Natural Gas Spot Price (Dollars per Million Btu)
# Date
# 1997-01-07                                               3.82
# 1997-01-08                                               3.80
# 1997-01-09                                               3.61
#             Henry Hub Natural Gas Spot Price (Dollars per Million Btu)
# Date
# 2018-11-09                                               3.74
# 2018-11-12                                               3.96
# 2018-11-13                                               4.10

# %%
# NYMEX Natural Gas Futures
with open(DATA_PATH + 'NG_Futures.csv', 'r') as f:
  df_Futures = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_Futures.head(3), df_Futures.tail(3))
# Out:
#             Natural Gas Futures Contract 1 (Dollars per Million Btu)  \
# Date
# 1993-12-20                                                NaN
# 1993-12-21                                                NaN
# 1993-12-22                                                NaN
#
#             Natural Gas Futures Contract 2 (Dollars per Million Btu)  \
# Date
# 1993-12-20                                                NaN
# 1993-12-21                                                NaN
# 1993-12-22                                                NaN
#
#             Natural Gas Futures Contract 3 (Dollars per Million Btu)  \
# Date
# 1993-12-20                                                NaN
# 1993-12-21                                                NaN
# 1993-12-22                                                NaN
#
#             Natural Gas Futures Contract 4 (Dollars per Million Btu)
# Date
# 1993-12-20                                              1.894
# 1993-12-21                                              1.830
# 1993-12-22                                              1.859
#             Natural Gas Futures Contract 1 (Dollars per Million Btu)  \
# Date
# 2018-11-12                                              3.788
# 2018-11-13                                              4.101
# 2018-11-14                                              4.837
#
#             Natural Gas Futures Contract 2 (Dollars per Million Btu)  \
# Date
# 2018-11-12                                              3.800
# 2018-11-13                                              4.147
# 2018-11-14                                              4.898
#
#             Natural Gas Futures Contract 3 (Dollars per Million Btu)  \
# Date
# 2018-11-12                                              3.660
# 2018-11-13                                              4.019
# 2018-11-14                                              4.770
#
#             Natural Gas Futures Contract 4 (Dollars per Million Btu)
# Date
# 2018-11-12                                              3.293
# 2018-11-13                                              3.712
# 2018-11-14                                              4.472

# %%
# EIA Weekly Natural Gas Storage Report
with open(DATA_PATH + 'NG_Storage.csv', 'r') as f:
  df_Storage = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_Storage.head(3), df_Storage.tail(3))
# Out:
#                                    Source  East Region  Midwest Region  \
# Week ending
# 2010-01-01   Derived EIA Weekly Estimates          769             900
# 2010-01-08   Derived EIA Weekly Estimates          703             820
# 2010-01-15   Derived EIA Weekly Estimates          642             750
#
#              Mountain Region  Pacific Region  South Central Region  Salt  \
# Week ending
# 2010-01-01               195             268                   985   159
# 2010-01-08               185             257                   886   123
# 2010-01-15               176             246                   793    91
#
#              NonSalt  Total Lower 48
# Week ending
# 2010-01-01       826            3117
# 2010-01-08       763            2850
# 2010-01-15       702            2607
#               Source  East Region  Midwest Region  Mountain Region  \
# Week ending
# 2018-10-26   EIA-912          826             956              180
# 2018-11-02   EIA-912          831             980              182
# 2018-11-09   EIA-912          835             991              181
#
#              Pacific Region  South Central Region  Salt  NonSalt  \
# Week ending
# 2018-10-26              262                   919   234      686
# 2018-11-02              265                   949   253      696
# 2018-11-09              266                   974   272      702
#
#              Total Lower 48
# Week ending
# 2018-10-26             3143
# 2018-11-02             3208
# 2018-11-09             3247

# %%
# EIA Monthly Gross Withdrawals and Production
with open(DATA_PATH + 'Production.csv', 'r') as f:
  df_Production = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_Production.head(3), df_Production.tail(3))
# Out:
#             U.S. Natural Gas Gross Withdrawals (MMcf)  \
# Date
# 1973-01-01                                        NaN
# 1973-02-01                                        NaN
# 1973-03-01                                        NaN
#
#             U.S. Natural Gas Gross Withdrawals from Gas Wells (MMcf)  \
# Date
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Oil Wells (MMcf)  \
# Date
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Shale Gas (Million Cubic Feet)  \
# Date
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Coalbed Wells (MMcf)  \
# Date
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
#
#             U.S. Natural Gas Repressuring (MMcf)  \
# Date
# 1973-01-01                                   NaN
# 1973-02-01                                   NaN
# 1973-03-01                                   NaN
#
#             U.S. Natural Gas Vented and Flared (MMcf)  \
# Date
# 1973-01-01                                        NaN
# 1973-02-01                                        NaN
# 1973-03-01                                        NaN
#
#             U.S. Nonhydrocarbon Gases Removed from Natural Gas (MMcf)  \
# Date
# 1973-01-01                                                NaN
# 1973-02-01                                                NaN
# 1973-03-01                                                NaN
#
#             U.S. Natural Gas Marketed Production (MMcf)  \
# Date
# 1973-01-01                                      1948000
# 1973-02-01                                      1962000
# 1973-03-01                                      1907000
#
#             U.S. Natural Gas Plant Liquids Production (Million Cubic Feet)  \
# Date
# 1973-01-01                                              79000
# 1973-02-01                                              79000
# 1973-03-01                                              77000
#
#             U.S. Dry Natural Gas Production (MMcf)  Unnamed: 12
# Date
# 1973-01-01                                     NaN          NaN
# 1973-02-01                                     NaN          NaN
# 1973-03-01                                     NaN          NaN
#             U.S. Natural Gas Gross Withdrawals (MMcf)  \
# Date
# 2018-06-01                                  2954943.0
# 2018-07-01                                  3106695.0
# 2018-08-01                                  3178843.0
#
#             U.S. Natural Gas Gross Withdrawals from Gas Wells (MMcf)  \
# Date
# 2018-06-01                                                NaN
# 2018-07-01                                                NaN
# 2018-08-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Oil Wells (MMcf)  \
# Date
# 2018-06-01                                                NaN
# 2018-07-01                                                NaN
# 2018-08-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Shale Gas (Million Cubic Feet)  \
# Date
# 2018-06-01                                                NaN
# 2018-07-01                                                NaN
# 2018-08-01                                                NaN
#
#             U.S. Natural Gas Gross Withdrawals from Coalbed Wells (MMcf)  \
# Date
# 2018-06-01                                                NaN
# 2018-07-01                                                NaN
# 2018-08-01                                                NaN
#
#             U.S. Natural Gas Repressuring (MMcf)  \
# Date
# 2018-06-01                                   NaN
# 2018-07-01                                   NaN
# 2018-08-01                                   NaN
#
#             U.S. Natural Gas Vented and Flared (MMcf)  \
# Date
# 2018-06-01                                        NaN
# 2018-07-01                                        NaN
# 2018-08-01                                        NaN
#
#             U.S. Nonhydrocarbon Gases Removed from Natural Gas (MMcf)  \
# Date
# 2018-06-01                                                NaN
# 2018-07-01                                                NaN
# 2018-08-01                                                NaN
#
#             U.S. Natural Gas Marketed Production (MMcf)  \
# Date
# 2018-06-01                                      2641008
# 2018-07-01                                      2782326
# 2018-08-01                                      2843746
#
#             U.S. Natural Gas Plant Liquids Production (Million Cubic Feet)  \
# Date
# 2018-06-01                                             187394
# 2018-07-01                                             197213
# 2018-08-01                                             203516
#
#             U.S. Dry Natural Gas Production (MMcf)  Unnamed: 12
# Date
# 2018-06-01                               2453614.0          NaN
# 2018-07-01                               2585113.0          NaN
# 2018-08-01                               2640230.0          NaN

# %%
# US Temperature
with open(DATA_PATH + 'Temperature.csv', 'r') as f:
  df_Temperature = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_Temperature.head(3), df_Temperature.tail(3))
# Out:
#               Avg    Min    Max
# Date
# 2018-11-19  15.82  11.43  20.20
# 2018-11-18  15.48  11.03  19.93
# 2018-11-17  15.91  11.38  20.44
#               Avg   Min    Max
# Date
# 2013-11-29  14.48  9.06  19.90
# 2013-11-28  13.96  8.75  19.17
# 2013-11-27  14.47  9.53  19.40

# %%
# NOAA Arctic Oscillation Index
with open(DATA_PATH + 'AO_Index.csv', 'r') as f:
  df_AOI = pd.read_csv(f, header = None, index_col = 0, parse_dates = [[0, 1, 2]])
  display(df_AOI.head(3), df_AOI.tail(3))
# Out:
#                 3
# 0_1_2
# 1979-01-01 -1.556
# 1979-01-02 -0.888
# 1979-01-03  0.255
#                 3
# 0_1_2
# 2018-10-29  0.508
# 2018-10-30  0.754
# 2018-10-31  0.776

# %%
# Crude Oil WTI Futures
with open(DATA_PATH + 'WTI_Futures.csv', 'r') as f:
  df_WTI = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_WTI.head(3), df_WTI.tail(3))
# Out:
#             Price   Open   High    Low     Vol. Change %
# Date
# 2018-11-19  56.98  57.31  57.55  56.83        -   -0.56%
# 2018-11-18  57.30  57.00  57.36  56.93        -    1.49%
# 2018-11-16  56.46  56.58  57.96  55.89  159.00K    0.00%
#             Price   Open   High    Low    Vol. Change %
# Date
# 1990-01-04  23.41  23.90  23.92  22.83  53.07K   -1.14%
# 1990-01-03  23.68  23.19  23.80  23.00  50.06K    3.45%
# 1990-01-02  22.89  21.81  22.92  21.79  45.18K    4.90%

# %%
# US Dollar Index
with open(DATA_PATH + 'Dollar_Index.csv', 'r') as f:
  df_DI = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_DI.head(3), df_DI.tail(3))
# Out:
#             Price   Open   High    Low Vol. Change %
# Date
# 2018-11-19  96.36  96.45  96.57  96.32    -   -0.07%
# 2018-11-18  96.43  96.43  96.45  96.38    -   -0.04%
# 2018-11-16  96.47  97.05  97.06  96.40    -   -0.47%
#             Price   Open   High    Low Vol. Change %
# Date
# 1990-01-03  94.42  94.15  94.52  94.08    -    0.14%
# 1990-01-02  94.29  93.13  94.31  93.08    -    1.16%
# 1990-01-01  93.21  93.19  93.31  93.08    -    0.00%

# %% [markdown]
# ## 데이터 준비 II : CFTC  Non-Commercial  Net Positions
# * https://colab.research.google.com/drive/1YvdML1V_0VCqwkPCny528AIPjCZUbIYw

# %%
# CFTC Weekly Non-Commercial Net Positions = COTDLC (M)
with open(DATA_PATH + 'CFTC.csv', 'r') as f:
  df_CFTC = pd.read_csv(f, index_col = 0, parse_dates = True)
  display(df_CFTC.head(3), df_CFTC.tail(3))
# Out:
#             COTDLC (M)  COTDLC (O)  COTDLC (P)  COTDLC (S)  COTLC (C)  \
# date
# 2018-11-21      279113     -256767      -50347       -9794     -60141
# 2018-11-20      279113     -256767      -50347       -9794     -60141
# 2018-11-19      279113     -256767      -50347       -9794     -60141
#
#             COTLC (L)  COTLC (S)   Interest    Volume  close  high  low  open  \
# date
# 2018-11-21      22346      37795        NaN       NaN      5     5    5     5
# 2018-11-20      22346      37795        NaN  697315.0      5     5    4     5
# 2018-11-19      22346      37795  1381403.0  805724.0      5     5    4     5
#
#            symbol
# date
# 2018-11-21  NGZ18
# 2018-11-20  NGZ18
# 2018-11-19  NGZ18
#             COTDLC (M)  COTDLC (O)  COTDLC (P)  COTDLC (S)  COTLC (C)  \
# date
# 2012-11-05       36281      -85285      -40316       48164       7848
# 2012-11-02       36281      -85285      -40316       48164       7848
# 2012-11-01       36281      -85285      -40316       48164       7848
#
#             COTLC (L)  COTLC (S)   Interest    Volume  close  high  low  open  \
# date
# 2012-11-05     -49004      41156  1175941.0  217603.0      4     4    4     4
# 2012-11-02     -49004      41156  1185202.0  290111.0      4     4    4     4
# 2012-11-01     -49004      41156  1185202.0  272918.0      4     4    4     4
#
#            symbol
# date
# 2012-11-05  NGZ12
# 2012-11-02  NGZ12
# 2012-11-01  NGZ12

# %% [markdown]
# ## 데이터 통합

# %%
M = pd.concat([ df_DJCI['Dow Jones Commodity Index Natural Gas TR'],
                df_Spot,
                df_Futures['Natural Gas Futures Contract 1 (Dollars per Million Btu)'],
                df_Storage['Total Lower 48'],
                df_Production['U.S. Natural Gas Gross Withdrawals (MMcf)'],
                df_Temperature['Avg'],
                df_AOI,
                df_WTI['Price'],
                df_DI['Price'],
                df_CFTC['COTDLC (M)'] ], axis = 1)

M.columns = ['DJCI', 'Spot', 'Futures', 'Storage', 'Production', 'Temperature', 'AOI', 'WTI', 'DI', 'CFTC']
M.index.name = 'Date'

M.tail(10)
# Out:
#             DJCI  Spot  Futures  Storage  Production  Temperature  AOI    WTI  \
# Date
# 2018-11-12  0.76  3.96    3.788      NaN         NaN        16.20  NaN  59.93
# 2018-11-13  0.82  4.10    4.101      NaN         NaN        15.82  NaN  55.69
# 2018-11-14  0.97   NaN    4.837      NaN         NaN        15.25  NaN  56.25
# 2018-11-15  0.80   NaN      NaN      NaN         NaN        15.45  NaN  56.46
# 2018-11-16  0.85   NaN      NaN      NaN         NaN        15.79  NaN  56.46
# 2018-11-17   NaN   NaN      NaN      NaN         NaN        15.91  NaN    NaN
# 2018-11-18   NaN   NaN      NaN      NaN         NaN        15.48  NaN  57.30
# 2018-11-19   NaN   NaN      NaN      NaN         NaN        15.82  NaN  56.98
# 2018-11-20   NaN   NaN      NaN      NaN         NaN          NaN  NaN    NaN
# 2018-11-21   NaN   NaN      NaN      NaN         NaN          NaN  NaN    NaN
#
#                DI      CFTC
# Date
# 2018-11-12  97.54  245106.0
# 2018-11-13  97.30  279113.0
# 2018-11-14  96.80  279113.0
# 2018-11-15  96.93  279113.0
# 2018-11-16  96.47  279113.0
# 2018-11-17    NaN       NaN
# 2018-11-18  96.43       NaN
# 2018-11-19  96.36  279113.0
# 2018-11-20    NaN  279113.0
# 2018-11-21    NaN  279113.0

# %%
M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14642 entries, 1973-01-01 to 2018-11-21
# Data columns (total 10 columns):
# DJCI           2532 non-null float64
# Spot           5500 non-null float64
# Futures        6230 non-null float64
# Storage        463 non-null float64
# Production     464 non-null float64
# Temperature    1819 non-null float64
# AOI            14548 non-null float64
# WTI            7312 non-null float64
# DI             7486 non-null float64
# CFTC           1526 non-null float64
# dtypes: float64(10)
# memory usage: 1.2 MB

# %% [markdown]
# ## 결측치 처리

# %%
M.isnull().sum()
# Out:
# DJCI           12110
# Spot            9142
# Futures         8412
# Storage        14179
# Production     14178
# Temperature    12823
# AOI               94
# WTI             7330
# DI              7156
# CFTC           13116
# dtype: int64

# %%
M['Production'] = M['Production'].apply(lambda x : x / 30)

M.fillna(method = 'ffill', inplace = True)
M.dropna(inplace = True)

display(M.head(3), M.tail(3))
# Out:
#             DJCI  Spot  Futures  Storage    Production  Temperature    AOI  \
# Date
# 2013-11-27  1.81  3.87    3.895   3775.0  81838.966667        14.47 -0.050
# 2013-11-28  1.81  3.87    3.895   3775.0  81838.966667        13.96 -0.399
# 2013-11-29  1.84  3.87    3.954   3613.0  81838.966667        14.48 -0.162
#
#               WTI     DI     CFTC
# Date
# 2013-11-27  92.30  80.72 -17803.0
# 2013-11-28  92.28  80.72 -17803.0
# 2013-11-29  92.72  80.68 -17803.0
#             DJCI  Spot  Futures  Storage     Production  Temperature    AOI  \
# Date
# 2018-11-19  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
# 2018-11-20  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
# 2018-11-21  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
#
#               WTI     DI      CFTC
# Date
# 2018-11-19  56.98  96.36  279113.0
# 2018-11-20  56.98  96.36  279113.0
# 2018-11-21  56.98  96.36  279113.0

# %% [markdown]
# ## EDA

# %%
M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1821 entries, 2013-11-27 to 2018-11-21
# Data columns (total 10 columns):
# DJCI           1821 non-null float64
# Spot           1821 non-null float64
# Futures        1821 non-null float64
# Storage        1821 non-null float64
# Production     1821 non-null float64
# Temperature    1821 non-null float64
# AOI            1821 non-null float64
# WTI            1821 non-null float64
# DI             1821 non-null float64
# CFTC           1821 non-null float64
# dtypes: float64(10)
# memory usage: 156.5 KB

# %%
M.describe()
# Out:
#               DJCI         Spot      Futures      Storage     Production  \
# count  1821.000000  1821.000000  1821.000000  1821.000000    1821.000000
# mean      1.084580     3.124986     3.111292  2687.683690   92385.811862
# std       0.587599     0.835860     0.750207   804.846956    5795.818176
# min       0.510000     1.490000     1.639000   824.000000   78565.933333
# 25%       0.640000     2.710000     2.704000  2158.000000   88671.933333
# 50%       0.790000     2.930000     2.924000  2767.000000   91622.800000
# 75%       1.320000     3.440000     3.391000  3311.000000   94103.466667
# max       2.570000     8.150000     6.149000  4047.000000  105961.433333
#
#        Temperature          AOI          WTI           DI           CFTC
# count  1821.000000  1821.000000  1821.000000  1821.000000    1821.000000
# mean     19.021367     0.404814    61.136485    92.865151   27142.090610
# std       3.042696     1.219158    20.201837     6.330860  120640.221891
# min      11.170000    -3.151000    26.210000    79.090000 -233984.000000
# 25%      16.350000    -0.444000    47.080000    90.050000  -64005.000000
# 50%      19.460000     0.380000    53.400000    94.760000   43421.000000
# 75%      21.890000     1.205000    69.120000    96.980000  121872.000000
# max      23.760000     4.635000   107.260000   103.300000  279113.000000

# %%
M.isnull().sum()
# Out:
# DJCI           0
# Spot           0
# Futures        0
# Storage        0
# Production     0
# Temperature    0
# AOI            0
# WTI            0
# DI             0
# CFTC           0
# dtype: int64

# %%
m2season = { 3 : 'Spring' , 6 : 'Summer' ,  9 : 'Fall' , 12 : 'Winter' ,
             4 : 'Spring' , 7 : 'Summer' , 10 : 'Fall' ,  1 : 'Winter' ,
             5 : 'Spring' , 8 : 'Summer' , 11 : 'Fall' ,  2 : 'Winter' }

M['Season'] = M.index.map(lambda x : m2season[x.month])

sns.pairplot(M, hue='Season', palette='husl')
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/nonparametric/kde.py:475: DeprecationWarning: object of type <class 'numpy.float64'> cannot be safely interpreted as an integer.
#   grid,delta = np.linspace(a,b,gridsize,retstep=True)

# %%
M.corr()
# Out:
#                  DJCI      Spot   Futures   Storage  Production  Temperature  \
# DJCI         1.000000  0.758383  0.797751 -0.301613   -0.605301    -0.103899
# Spot         0.758383  1.000000  0.944740 -0.320256   -0.342075    -0.187654
# Futures      0.797751  0.944740  1.000000 -0.291441   -0.362506    -0.140197
# Storage     -0.301613 -0.320256 -0.291441  1.000000    0.041983    -0.007805
# Production  -0.605301 -0.342075 -0.362506  0.041983    1.000000     0.132875
# Temperature -0.103899 -0.187654 -0.140197 -0.007805    0.132875     1.000000
# AOI         -0.096499 -0.124483 -0.159480 -0.030113    0.018861     0.041976
# WTI          0.767111  0.819619  0.845422 -0.470509   -0.216482    -0.017813
# DI          -0.792631 -0.730256 -0.740016  0.399718    0.354905     0.055881
# CFTC        -0.003863  0.499694  0.527967 -0.303042    0.198826    -0.085589
#
#                   AOI       WTI        DI      CFTC
# DJCI        -0.096499  0.767111 -0.792631 -0.003863
# Spot        -0.124483  0.819619 -0.730256  0.499694
# Futures     -0.159480  0.845422 -0.740016  0.527967
# Storage     -0.030113 -0.470509  0.399718 -0.303042
# Production   0.018861 -0.216482  0.354905  0.198826
# Temperature  0.041976 -0.017813  0.055881 -0.085589
# AOI          1.000000 -0.175875  0.084647 -0.153016
# WTI         -0.175875  1.000000 -0.881750  0.422311
# DI           0.084647 -0.881750  1.000000 -0.212973
# CFTC        -0.153016  0.422311 -0.212973  1.000000

# %%
M.drop(columns=['Season'], inplace = True)

# %%
for i in range(len(M.columns)):
  plt.subplots(figsize = (16,3))
  sns.lineplot(x = M.index, y = M.columns[i], data = M)
  plt.show()

# %% [markdown]
# ## 데이터 정규화

# %%
#N = M.dropna().apply(scale, axis = 'index', raw = True)
#N.head(5)

# %%
#N.describe()

# %% [markdown]
# ## ARIMA : Facebook Prophet

# %%
#N1 = N.reset_index()
N1 = M.dropna().reset_index()
N1.rename(columns={'Date':'ds', 'DJCI' :'y'}, inplace=True)

N1.dropna(inplace=True)
N1.head(5)
# Out:
#           ds     y  Spot  Futures  Storage    Production  Temperature    AOI  \
# 0 2013-11-27  1.81  3.87    3.895   3775.0  81838.966667        14.47 -0.050
# 1 2013-11-28  1.81  3.87    3.895   3775.0  81838.966667        13.96 -0.399
# 2 2013-11-29  1.84  3.87    3.954   3613.0  81838.966667        14.48 -0.162
# 3 2013-11-30  1.84  3.87    3.954   3613.0  81838.966667        15.21  0.451
# 4 2013-12-01  1.84  3.87    3.954   3613.0  84198.900000        16.03  1.088
#
#      WTI     DI     CFTC
# 0  92.30  80.72 -17803.0
# 1  92.28  80.72 -17803.0
# 2  92.72  80.68 -17803.0
# 3  92.72  80.68 -17803.0
# 4  92.72  80.68 -17803.0

# %%
fb1 = Prophet(daily_seasonality = True, changepoint_prior_scale = 0.5, yearly_seasonality = 20)
fb1.fit(N1)

# %%
future1 = fb1.make_future_dataframe(periods = 60)
future1.tail()
# Out:
#              ds
# 1876 2019-01-16
# 1877 2019-01-17
# 1878 2019-01-18
# 1879 2019-01-19
# 1880 2019-01-20

# %%
forecast1 = fb1.predict(future1)
forecast1[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 1876 2019-01-16  0.758401    0.641175    0.859037
# 1877 2019-01-17  0.760737    0.642412    0.874766
# 1878 2019-01-18  0.764919    0.644324    0.874985
# 1879 2019-01-19  0.770980    0.638471    0.872951
# 1880 2019-01-20  0.777556    0.648888    0.889720

# %%
fig1 = fb1.plot(forecast1)
_ = add_changepoints_to_plot(fig1.gca(), fb1, forecast1)

# %%
_ = fb1.plot_components(forecast1)

# %%
_ = plot_yearly(fb1)

# %%
df_cv1 = cross_validation(fb1, initial='730 days', period='60 days', horizon = '365 days')
df_cv1.head()
# Out:
# INFO:fbprophet.diagnostics:Making 13 forecasts with cutoffs between 2015-12-02 00:00:00 and 2017-11-21 00:00:00
#           ds      yhat  yhat_lower  yhat_upper     y     cutoff
# 0 2015-12-03  0.690797    0.631800    0.745380  0.80 2015-12-02
# 1 2015-12-04  0.666441    0.613275    0.720538  0.80 2015-12-02
# 2 2015-12-05  0.649000    0.592967    0.706390  0.80 2015-12-02
# 3 2015-12-06  0.634878    0.576420    0.688339  0.80 2015-12-02
# 4 2015-12-07  0.614970    0.557289    0.666032  0.76 2015-12-02

# %%
df_p1 = performance_metrics(df_cv1)
df_p1.head()
# Out:
#      horizon       mse      rmse       mae      mape  coverage
# 766  37 days  0.050806  0.225402  0.152916  0.208140  0.443038
# 1496 37 days  0.050788  0.225362  0.152809  0.208009  0.445148
# 1861 37 days  0.050797  0.225382  0.152856  0.208107  0.447257
# 2956 37 days  0.050798  0.225385  0.152871  0.208128  0.447257
# 4051 37 days  0.050805  0.225400  0.152983  0.208317  0.447257

# %%
_ = plot_cross_validation_metric(df_cv1, metric='mape')

# %% [markdown]
# ## Deep Learning : Keras

# %%
look_back = 1

def create_dataset(dataset, look_back = 1):
  dataX, dataY = [], []
  
  for i in range(len(dataset) - look_back - 1):
    a = dataset[i:(i + look_back), :]
    dataX.append(a)
    dataY.append(dataset[i + look_back])
    
  return np.array(dataX), np.array(dataY)

# %%
scaler = MinMaxScaler(feature_range = (0, 1))
N2 = scaler.fit_transform(M.astype(np.float))

# %%
print(N2)
# Out:
# [[0.63106796 0.35735736 0.50022173 ... 0.81542258 0.06732755 0.42132579]
#  [0.63106796 0.35735736 0.50022173 ... 0.81517582 0.06732755 0.42132579]
#  [0.64563107 0.35735736 0.51330377 ... 0.82060457 0.06567534 0.42132579]
#  ...
#  [0.16504854 0.39189189 0.70909091 ... 0.3796422  0.71334159 1.        ]
#  [0.16504854 0.39189189 0.70909091 ... 0.3796422  0.71334159 1.        ]
#  [0.16504854 0.39189189 0.70909091 ... 0.3796422  0.71334159 1.        ]]

# %%
# split train, test
train_size = int(len(N2) * 0.9)
test_size  = len(N2) - train_size
train, test = N2[0:train_size], N2[train_size:len(N2)]

# %%
display(M[train_size:len(N2)].head(3), M[train_size:len(N2)].tail(3))
# Out:
#             DJCI  Spot  Futures  Storage     Production  Temperature    AOI  \
# Date
# 2018-05-23  0.58  2.89    2.914   1629.0  102725.133333        20.69 -0.562
# 2018-05-24  0.59  2.88    2.940   1629.0  102725.133333        21.14 -0.121
# 2018-05-25  0.59  2.88    2.939   1725.0  102725.133333        21.70  0.224
#
#               WTI     DI      CFTC
# Date
# 2018-05-23  71.84  94.00  198246.0
# 2018-05-24  70.71  93.76  198246.0
# 2018-05-25  67.88  94.19  198246.0
#             DJCI  Spot  Futures  Storage     Production  Temperature    AOI  \
# Date
# 2018-11-19  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
# 2018-11-20  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
# 2018-11-21  0.85   4.1    4.837   3247.0  105961.433333        15.82  0.776
#
#               WTI     DI      CFTC
# Date
# 2018-11-19  56.98  96.36  279113.0
# 2018-11-20  56.98  96.36  279113.0
# 2018-11-21  56.98  96.36  279113.0

# %%
# create dataset for learning
trainX, trainY = create_dataset(train)
testX , testY  = create_dataset(test)

# %%
# reshape input to be [samples, time steps, features]
n_features = testX.shape[2]
trainX = np.reshape(trainX, (trainX.shape[0], 1, n_features))
testX  = np.reshape(testX , (testX.shape[0] , 1, n_features))

# %%
trainX.shape[2]
# Out:
# 10

# %%
n_features
# Out:
# 10

# %%
# simple lstm network learning
model = Sequential()
model.add(LSTM(8, input_shape = (look_back, n_features)))
model.add(Dense(units = 10))
model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.fit(trainX, trainY, epochs = 10, batch_size = 1)
# Out:
# Epoch 1/10
# 1636/1636 [==============================] - 5s 3ms/step - loss: 0.0395
# Epoch 2/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0095
# Epoch 3/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0046
# Epoch 4/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0028
# Epoch 5/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0019
# Epoch 6/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0015
# Epoch 7/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0014
# Epoch 8/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0014
# Epoch 9/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0013
# Epoch 10/10
# 1636/1636 [==============================] - 4s 2ms/step - loss: 0.0012

# %%
# make prediction
testPredict = model.predict(testX)
testPredict = scaler.inverse_transform(testPredict)
testY = scaler.inverse_transform(testY)
testScore = math.sqrt(mean_squared_error(testY, testPredict))
print('Train Score: %.2f RMSE' % testScore)
# Out:
# Train Score: 7442.15 RMSE

# %%
data = {
    'testPredict' : testPredict[:, 0],
    'testY'       : testY[:, 0],
}

df_plot = pd.DataFrame(data)
#df_plot.plot(figsize = (16,3))

# %%
#len(df_plot), len(forecast1['yhat'][1638:1819].reset_index())
df_plot['prophet'] = forecast1['yhat'][1638:1819].reset_index(drop = True)

# %%
df_plot.plot(figsize = (16,3))
